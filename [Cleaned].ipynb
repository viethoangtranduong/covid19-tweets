# %%
import pandas as pd
data = pd.read_csv("data_country_random.csv")

# %%
data.head(5)
# Out:
#    Unnamed: 0             user_name         user_location  \
# 0           0          covidnews.ch           Switzerland
# 1           1        Rajesh Kshitij             hyderabad
# 2           2  www.seamartist.co.za          South Africa
# 3           3           George Hall  Melbourne, Australia
# 4           4       Jonathan Singer           Chicago, IL
#
#                                     user_description         user_created  \
# 0         Coronavirus Statistics, Information & News  2020-03-21 16:13:52
# 1                                    News 18 Network  2010-07-25 10:45:13
# 2  #madeinsouthafrica\n30%SALE➡️ONLINE ONLY\nhttp...  2010-10-18 14:51:26
# 3  Social Media volunteer Vic bushfires Feb '09, ...  2009-01-13 01:46:59
# 4  The first social work podcast by social worker...  2009-09-09 15:17:32
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0             361        1885.0              149              0
# ...

# %%
data.cleaned_text
# Out:
# 0      coronainfoch covid19 corona uk coronavirus 45 ...
# 1      puducherry 264 new covid19 positive cases 131 ...
# 2      shop lovely unisexshopper truelly remarkable b...
# 3      first dandenong broadmeadowsdan seems losing s...
# 4      loved talking carol tosone shared trauma covid...
#                              ...
# 870    telegraph odd public inquiry governments shamb...
# 871    done could uae schools ready safely welcome ba...
# 872    1 734 new covid19 positive cases reported odis...
# 873    20 football fanatics needed dm interested lago...
# 874    job family health choose sb1383 keep families ...
# Name: cleaned_text, Length: 875, dtype: object
