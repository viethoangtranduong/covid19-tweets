# %%
#importing necessery libraries for future analysis of the dataset
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
import seaborn as sns
np.random.seed(2020)

# %%
data = pd.read_csv("english_tweets.csv")
data.head(3)
# Out:
#   Unnamed: 0               user_name    user_location  \
# 0          0         Ageing Well B&H  Brighton & Hove
# 1          1     The Hindu - Chennai   Chennai, India
# 2          2  #COVID19: Stay at home     Accra, Ghana
#
#                                     user_description         user_created  \
# 0  We help people aged 50+ in Brighton & Hove fin...  2019-08-21 09:38:48
# 1  The official twitter account of The Hindu's re...  2012-06-20 11:24:09
# 2  Fact-checker | Journalist @Citi973 covering en...  2010-08-22 16:49:27
#
#   user_followers user_friends  user_favourites user_verified  \
# 0            267          347            569.0         False
# 1          90393          307            269.0          True
# 2           3103          623           6951.0         False
#
#                   date                                               text  \
# 0  2020-08-11 07:30:27  So much fun to be hard Dont miss out Email pau...
# ...

# %%
data.dropna(subset=['user_location', 'user_description', 'hashtags'], inplace=True)
data = data.drop(['Unnamed: 0'], axis = 1)

# %%
data = data.sample(n = 10000)
data.reset_index(inplace=True)
data.drop(["index"], axis = 1)
print(data.shape)
data.head(3)
# Out:
# (10000, 19)
#    index        user_name     user_location  \
# 0   9657            UNCDF      New York, NY
# 1   7845  Zachary Burkett        Austin, TX
# 2  14081      Reshma Jose  Chalakudy, India
#
#                                     user_description         user_created  \
# 0  Making Finance Work for the Poor: #LDCs, #Fina...  2013-05-15 15:37:50
# 1  I have NO FAITH in the Trump Administration. I...  2013-11-09 21:20:12
# 2                          Bold and beautiful......!  2019-03-21 04:22:32
#
#   user_followers user_friends  user_favourites user_verified  \
# 0          14838          936            404.0          True
# 1             35           87            409.0         False
# 2             44          191              7.0         False
#
#                   date                                               text  \
# 0  2020-08-11 08:34:02  Humans have unlimited needs but the planet has...
# 1  2020-08-14 04:12:05  realDonaldTrump you will never run away from C...
# ...

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="twitter")

def get_nation(txt):
    try: 
        if txt == "Global" or txt == "US and abroad":
            return "United States"
        location = geolocator.geocode(txt)
        x = location.address.split(",")[-1]
        while x[0] == " ":
            x = x[1:]
        if x == "United States of America":
            return "United States"
        return x
    except:
        return np.nan


data["country"] = data.user_location.apply(get_nation)

# %%
data.head()
# Out:
#    index        user_name               user_location  \
# 0   9657            UNCDF                New York, NY
# 1   7845  Zachary Burkett                  Austin, TX
# 2  14081      Reshma Jose            Chalakudy, India
# 3  12003        @Caerdael                      Genève
# 4  22598    Douglas Clark  University of Saskatchewan
#
#                                     user_description         user_created  \
# 0  Making Finance Work for the Poor: #LDCs, #Fina...  2013-05-15 15:37:50
# 1  I have NO FAITH in the Trump Administration. I...  2013-11-09 21:20:12
# 2                          Bold and beautiful......!  2019-03-21 04:22:32
# 3  Artiste peintre \n \n@IFJGlobal @ICIJorg @amne...  2010-03-15 16:16:41
# 4  Associate Professor at @usaskSENS. Tweets on h...  2012-10-05 15:56:52
#
#   user_followers user_friends  user_favourites user_verified  \
# 0          14838          936            404.0          True
# 1             35           87            409.0         False
# ...

# %%
data.head()
# Out:
#    index        user_name               user_location  \
# 0   9657            UNCDF                New York, NY
# 1   7845  Zachary Burkett                  Austin, TX
# 2  14081      Reshma Jose            Chalakudy, India
# 3  12003        @Caerdael                      Genève
# 4  22598    Douglas Clark  University of Saskatchewan
#
#                                     user_description         user_created  \
# 0  Making Finance Work for the Poor: #LDCs, #Fina...  2013-05-15 15:37:50
# 1  I have NO FAITH in the Trump Administration. I...  2013-11-09 21:20:12
# 2                          Bold and beautiful......!  2019-03-21 04:22:32
# 3  Artiste peintre \n \n@IFJGlobal @ICIJorg @amne...  2010-03-15 16:16:41
# 4  Associate Professor at @usaskSENS. Tweets on h...  2012-10-05 15:56:52
#
#   user_followers user_friends  user_favourites user_verified  \
# 0          14838          936            404.0          True
# 1             35           87            409.0         False
# ...

# %%
x = data

# %%
data = x

# %%
data.dropna(subset=['country'], inplace=True)
data = data.drop(["index"], axis = 1)
data.reset_index(inplace=True)
data = data.drop(["index"], axis = 1)
print(data.shape)
data.head(10)
# Out:
# (8981, 19)
#          user_name               user_location  \
# 0            UNCDF                New York, NY
# 1  Zachary Burkett                  Austin, TX
# 2      Reshma Jose            Chalakudy, India
# 3        @Caerdael                      Genève
# 4    Douglas Clark  University of Saskatchewan
# 5     IAM Platform                   Worldwide
# 6           azeefa                Virudhunagar
# 7       NewsMobile                       India
# 8    YWCA Edmonton    Edmonton, Alberta Canada
# 9  Dr. Theresa Tam                      Canada
#
#                                     user_description         user_created  \
# 0  Making Finance Work for the Poor: #LDCs, #Fina...  2013-05-15 15:37:50
# 1  I have NO FAITH in the Trump Administration. I...  2013-11-09 21:20:12
# 2                          Bold and beautiful......!  2019-03-21 04:22:32
# 3  Artiste peintre \n \n@IFJGlobal @ICIJorg @amne...  2010-03-15 16:16:41
# ...

# %%
from collections import Counter
x = Counter(data.country)
x.most_common(5)
# Out:
# [('United States', 2979),
#  ('India', 1652),
#  ('United Kingdom', 1073),
#  ('Canada', 497),
#  ('Australia', 340)]

# %%
data.user_verified = data.user_verified.map({False: 0, True: 1})
data.is_retweet = data.is_retweet.map({False: 0, True: 1})

# %%
data.head(2)
# Out:
#          user_name user_location  \
# 0            UNCDF  New York, NY
# 1  Zachary Burkett    Austin, TX
#
#                                     user_description         user_created  \
# 0  Making Finance Work for the Poor: #LDCs, #Fina...  2013-05-15 15:37:50
# 1  I have NO FAITH in the Trump Administration. I...  2013-11-09 21:20:12
#
#   user_followers user_friends  user_favourites  user_verified  \
# 0          14838          936            404.0            NaN
# 1             35           87            409.0            NaN
#
#                   date                                               text  \
# 0  2020-08-11 08:34:02  Humans have unlimited needs but the planet has...
# 1  2020-08-14 04:12:05  realDonaldTrump you will never run away from C...
#
#               hashtags  is_retweet           mention  \
# 0  ['SDGs', 'COVID19']           0               NaN
# 1          ['COVID19']           0  @realDonaldTrump
#
# ...

# %%
data['date'] = pd.to_datetime(data['date']) 
data['day'] = data['date'].astype(str).str.split(' ', expand=True)[0]
data['time'] = data['date'].astype(str).str.split(' ', expand=True)[1]

# %%
data.to_csv("data_country_random.csv")
