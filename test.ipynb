# %%
# Insert code here.
import nltk
nltk.download('punkt') # one time execution
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
import re
from nltk.tokenize import word_tokenize

def clean_text(txt): 
    try: 
        txt = re.sub(r'\W+', ' ', txt)
        txt = txt.lower()
        txt = txt.replace("[^a-zA-Z]", " ")
        word_tokens = word_tokenize(txt)
        filtered_word = [w for w in word_tokens if not w in stop_words] 
        filtered_word = [w for w in filtered_word if all(ord(c) < 128 for c in w)]
        filtered_word = [w + " " for w in filtered_word]
        return "".join(filtered_word)
    except:
        return np.nan
# Out:
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
txt = '''archaeologyðŸ¥š
GENIOUSðŸš¬
Inferno DeluxeðŸ¦»
talented in many waysðŸ’«
I hate lies ðŸ§Ÿâ€â™‚ï¸
You can't make joke of meðŸ–•
i like ChristmassðŸ¥‚
its easier with good musicðŸŒ'''
clean_text(txt)
# Out:
# 'inferno talented in many i hate lies you can t make joke of i like its easier with good '

# %%
lst = []
for word in word_tokenize(txt):
    if all(ord(c) < 128 for c in word):
        lst.append(word)

# %%
lst
# Out:
# ['Inferno',
#  'talented',
#  'in',
#  'many',
#  'I',
#  'hate',
#  'lies',
#  'You',
#  'ca',
#  "n't",
#  'make',
#  'joke',
#  'of',
#  'i',
#  'like',
#  'its',
#  'easier',
#  'with',
#  'good']
